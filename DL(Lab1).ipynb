# %%
import tensorflow as tf
import pandas as pd
import numpy as np

#step1: Convert data to numpy arrays
x=np.array([1,2,3,4], dtype=float)
y=np.array([2,4,6,8], dtype=float)

#Step2: Define model using Input layer(recommended)
model=tf.keras.Sequential([
    tf.keras.Input(shape=(1,)),
    tf.keras.layers.Dense(1)
])

#Step3: Compile the model
model.compile(optimizer='sgd',loss='mean_squared_error')

#Step4: Train the model
model.fit(x,y,epochs=10)
# 1. Epoch--One complete pass of the training data through the model
    # An epoch is one complete pass of the entire training dataset through a machine learning
      # or deep learning model during training.'''
# Out:
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - loss: 28.3564
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 19.6935
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 13.6824
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 9.5114
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 6.6170
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 4.6086
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 3.2149
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 2.2477
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 1.5766
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 1.1107

# %% [markdown]
# ***KERAS***

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense


model=Sequential([
    Dense(1, input_shape=(1,))
])

model.compile(optimizer='sgd',loss='mse')
model.fit(x,y,epochs=10)
# Out:
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - loss: 32.9974
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 22.9167
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 15.9218
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 11.0680
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 7.7000
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 5.3629
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 3.7411
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 2.6156
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 1.8346
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 1.2925

# %% [markdown]
# ***PyTorch***

# %%
# !pip install torch torchvision torchaudio

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# Define a simple linear model
model = nn.Linear(1, 1)

# Loss and optimizer
criterion = nn.MSELoss()
optimizer = optim.SGD(model.parameters(), lr=0.01)

# Dummy data (convert to float)
x = torch.tensor([[1.], [2.], [3.], [4.]])
y = torch.tensor([[2.], [4.], [6.], [8.]])

# Training loop
for epoch in range(10):
    optimizer.zero_grad()
    outputs = model(x)
    loss = criterion(outputs, y)
    loss.backward()
    optimizer.step()
    print(f"Epoch {epoch+1}, Loss: {loss.item()}")
# Out:
# Epoch 1, Loss: 42.019676208496094
# Epoch 2, Loss: 29.156566619873047
# Epoch 3, Loss: 20.231124877929688
# Epoch 4, Loss: 14.03795051574707
# Epoch 5, Loss: 9.740635871887207
# Epoch 6, Loss: 6.758821487426758
# Epoch 7, Loss: 4.6898040771484375
# Epoch 8, Loss: 3.2541565895080566
# Epoch 9, Loss: 2.257991313934326
# Epoch 10, Loss: 1.5667719841003418
# Epoch 11, Loss: 1.0871498584747314
# Epoch 12, Loss: 0.7543506622314453
# Epoch 13, Loss: 0.5234280824661255
# Epoch 14, Loss: 0.36319616436958313
# Epoch 15, Loss: 0.25201427936553955
# Epoch 16, Loss: 0.17486782371997833
# Epoch 17, Loss: 0.12133724987506866
# Epoch 18, Loss: 0.08419375121593475
# Epoch 19, Loss: 0.05842071771621704
# Epoch 20, Loss: 0.04053724929690361
